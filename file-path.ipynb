# %%
from bs4 import BeautifulSoup
import urllib.request as req
import io

key = '796143536a756e69313134667752417a'
contentType = 'xml'
startIndex = '1'
endIndex = '100'
date = '20201010'

url = 'http://openapi.seoul.go.kr:8088/'+key+'/'+contentType+'/CardSubwayStatsNew/'+startIndex+'/'+endIndex+'/'+date+'/'
savename = 'subway.xml'
req.urlretrieve(url, savename)

xml = open(savename, 'r', encoding='utf-8').read()
soup = BeautifulSoup(xml, 'xml')

subwayList = []
for itemList in soup.find_all('row') :
    line_num = itemList.find('LINE_NUM').string
    sub_sta_nm = itemList.find('SUB_STA_NM').string
    ride_pasgr_num = itemList.find('RIDE_PASGR_NUM').string
    alight_pasgr_num = itemList.find('ALIGHT_PASGR_NUM').string
    subwayList.append((line_num, sub_sta_nm, ride_pasgr_num, alight_pasgr_num))

print('[ 서울시 지하철호선별 역별 승하차 인원 정보 ]')
for line_num, sub_sta_nm, ride_pasgr_num, alight_pasgr_num in subwayList :
    print(line_num+','+sub_sta_nm+','+ride_pasgr_num+','+alight_pasgr_num)
# Out:
# [ 서울시 지하철호선별 역별 승하차 인원 정보 ]
# 1호선,서울역,23944,22187
# 1호선,동묘앞,10807,11549
# 1호선,시청,7936,7715
# 1호선,종각,15327,15080
# 1호선,종로3가,18551,17528
# 1호선,종로5가,15447,15828
# 1호선,동대문,10207,10275
# 1호선,신설동,8152,7857
# 1호선,제기동,14005,14382
# 1호선,청량리(서울시립대입구),16548,16759
# 2호선,시청,6817,5771
# 2호선,을지로입구,17372,16976
# 2호선,을지로3가,7785,7837
# 2호선,을지로4가,6298,6307
# 2호선,동대문역사문화공원(DDP),8811,9403
# 2호선,신당,9581,9857
# 2호선,상왕십리,8196,7631
# 2호선,왕십리(성동구청),11500,9818
# 2호선,한양대,3549,3709
# 2호선,뚝섬,11034,11726
# 2호선,성수,13487,15565
# 2호선,건대입구,28781,32175
# 2호선,구의(광진구청),14075,13666
# 2호선,강변(동서울터미널),23427,22651
# 2호선,잠실나루,6755,6483
# 2호선,잠실(송파구청),49296,46038
# 2호선,잠실새내,13227,14164
# 2호선,종합운동장,4142,4565
# 2호선,삼성(무역센터),20313,20262
# 2호선,선릉,20179,17976
# 2호선,역삼,15093,16804
# 2호선,강남,51299,53401
# 2호선,교대(법원.검찰청),14463,16286
# 2호선,서초,8205,7569
# 2호선,방배,8733,8795
# 2호선,사당,25566,28930
# 2호선,낙성대(강감찬),19193,17671
# 2호선,서울대입구(관악구청),33221,32285
# 2호선,봉천,15204,13890
# 2호선,신림,43639,41908
# 2호선,신대방,17933,17038
# 2호선,구로디지털단지,30071,29423
# 2호선,대림(구로구청),16681,17541
# 2호선,신도림,33843,34476
# 2호선,문래,10181,10658
# 2호선,영등포구청,10050,10458
# 2호선,당산,11415,12103
# 2호선,합정,22361,24964
# 2호선,홍대입구,48049,54084
# 2호선,신촌,24949,25768
# 2호선,이대,8377,8651
# 2호선,아현,6623,6147
# 2호선,충정로(경기대입구),4586,4751
# 2호선,용답,1822,1658
# 2호선,신답,877,853
# 2호선,신설동,2827,2800
# 2호선,도림천,715,707
# 2호선,양천구청,3640,3643
# 2호선,신정네거리,6181,6125
# 2호선,용두(동대문구청),1436,1465
# 3호선,지축,2135,2066
# 3호선,구파발,13723,13806
# 3호선,연신내,27418,25949
# 3호선,불광,11630,13268
# 3호선,녹번,8540,7497
# 3호선,홍제,11797,10906
# 3호선,무악재,2389,2449
# 3호선,독립문,5420,5929
# 3호선,경복궁(정부서울청사),11769,13031
# 3호선,안국,10546,12691
# 3호선,종로3가,4303,6673
# 3호선,을지로3가,3957,4639
# 3호선,동대입구,5124,6108
# 3호선,약수,7926,7645
# 3호선,금호,5355,4822
# 3호선,옥수,6317,6303
# 3호선,압구정,21761,22989
# 3호선,신사,20771,22563
# 3호선,잠원,3582,3482
# 3호선,고속터미널,40011,38602
# 3호선,교대(법원.검찰청),5447,3409
# 3호선,남부터미널(예술의전당),16951,16759
# 3호선,양재(서초구청),16136,17962
# 3호선,매봉,4946,4868
# 3호선,도곡,2730,2689
# 3호선,대치,7578,6857
# 3호선,학여울,1002,929
# 3호선,대청,5049,4754
# 3호선,일원,4091,4055
# 3호선,수서,10604,10067
# 3호선,가락시장,5563,5349
# 3호선,경찰병원,3408,3393
# 3호선,오금,3695,3475
# 4호선,수유(강북구청),23181,22627
# 4호선,미아(서울사이버대학),9843,9354
# 4호선,미아사거리,19296,18731
# 4호선,길음,12089,11184
# 4호선,성신여대입구(돈암),15368,14339
# 4호선,한성대입구(삼선교),9235,9224
# 4호선,혜화,21299,22438

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import io



key = 'IlQuvwbMhQpoq5AqwRKt7iua3SCIVLL8FAs0kVHdoK8J7zHmn3QMof%2F2l6tsfD2fDy8ee2svGf%2FpCOkY8YCW%2FQ%3D%3D'
contentType = 'xml'
startIndex = '1'
endIndex = '100'
date = '20201010'


url = 'http://apis.data.go.kr/B552061/frequentzoneLg/'+key+'/'+contentType+'/CardSubwayStatsNew/'+startIndex+'/'+endIndex+'/'+date+'/'
savename = 'accident.xml'
req.urlretrieve(url, savename)
# Out:
# -----------------------------------
# HTTPErrorTraceback (most recent call last)
# <ipython-input-3-cc4c1774c643> in <module>
#      14 url = 'http://apis.data.go.kr/B552061/frequentzoneLg/'+key+'/'+contentType+'/CardSubwayStatsNew/'+startIndex+'/'+endIndex+'/'+date+'/'
#      15 savename = 'accident.xml'
# ---> 16 req.urlretrieve(url, savename)
#
# ~\anaconda3\envs\pydatavenv\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = _splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ~\anaconda3\envs\pydatavenv\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\envs\pydatavenv\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\anaconda3\envs\pydatavenv\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\anaconda3\envs\pydatavenv\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\anaconda3\envs\pydatavenv\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\envs\pydatavenv\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 400: Bad Request

# %%
http://apis.data.go.kr/B552061/frequentzoneLg/getRestFrequentzoneLg
    # ?serviceKey=IlQuvwbMhQpoq5AqwRKt7iua3SCIVLL8FAs0kVHdoK8J7zHmn3QMof%2F2l6tsfD2fDy8ee2svGf%2FpCOkY8YCW%2FQ%3D%3D&
    searchYearCd=2017
    &siDo=11&
    guGun=200&
    type=xml&
    numOfRows=10
    &pageNo=1
