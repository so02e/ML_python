# %% [markdown]
# https://scikit-learn.org/
# 같은 알고리즘이더라도, 데이터에 따라서 성능이 달라진다.
# 요리의 조리도구처럼 사용하는 알고리즘..
#
#
# |                        Supervised Learning(지도학습)                        |                   Unsupervised Learning(비지도학습)                   |
# | :-------------------------------------------------------: | :-----------------------------------------------: |
# | 정답이 있는 데이터는 classification, regression 으로 예측 | 정답이 없는 데이터는 unsupervised 머신러닝을 사용 |

# %% [markdown]
# ### `classification(분류)` : 고객의 물건 구매, 제품의 불량, 대출 승인
# ### `regression(회귀)` : 재고량, 판매량, 매출액 예측
# ### `clustering(군집화)` : 고객의 군집화
# ### `Dimensionality reduction` : PCA 분석
# ### `Hyperparameter Optimization`
# ### `Evaluation Metrics`
# ### `semi-supervised learning`
# ### `Feature selection`
# ### `Feature Extraction`
# ### `out of core learning`

# %% [markdown]
# # 사이킷런이란?
#
# 사이킷런은 대표적인 파이썬 머신러닝 라이브러리입니다.
#
# 이 강의에서는 Classification(분류), Regression(회귀) 모델을 주로 사용합니다.
#
#
#
# # 머신러닝 알고리즘
#
# 알고리즘은 조리기구입니다! 우리는 알고리즘을 활용하여 데이터를 요리할 수 있습니다.
#
# 어떤 알고리즘을 사용하는 가에 따라 성능은 다르게 나타납니다.
#
#
#
# # 머신러닝 문제
#
# 크게는 정답이 있는 문제인 Supervised learning(지도학습)과 정답이 없는 Clustering(클러스터링), Dimensionality reduction(차원 축소)과 같은 문제를 해결하는 Unsupervised learning(비지도학습)으로 나뉩니다.

# %%
from sklearn import tree
X = [[0, 0], [1, 1]]
Y = [0, 1]

# %%
clf = tree.DecisionTreeClassifier()
clf
# Out:
# DecisionTreeClassifier()

# %%
clf = clf.fit(X, Y)
clf
# Out:
# DecisionTreeClassifier()

# %%
clf.predict([[2., 2.]])
# Out:
# array([1])

# %%
clf.predict_proba([[2., 2.]])
# Out:
# array([[0., 1.]])

# %%
from sklearn.datasets import load_iris
from sklearn import tree
X, y = load_iris(return_X_y=True)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
t = tree.plot_tree(clf.fit(X, y))
